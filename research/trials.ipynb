# %%
from langchain_community.document_loaders import PyPDFLoader, DirectoryLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS

# %%
PDFloader = PyPDFLoader('C:\\Personal\\AI_Handson\\Projects\\Medical_Chatbot_with_Langchain\\data\\Medical_Oncology_Handbook_.pdf')
# directoryLoader = DirectoryLoader(
#     path="C:\\Personal\\AI_Handson\\Projects\\Medical_Chatbot_with_Langchain\\data",
#     glob="*.pdf",
#     loader_cls=PyPDFLoader
# )

# %%
docs = PDFloader.load()
# for doc in docs:
#     print(doc)

text_splitter= RecursiveCharacterTextSplitter(
    chunk_size = 20,
    chunk_overlap = 5
)
text = text_splitter.split_documents(docs)

# %%
# print(docs[0].page_content)
# print(docs[0].metadata)
print(text[5])
# Out:
# page_content='DEPARTMENT OF' metadata={'producer': 'Microsoft® Word for Office 365', 'creator': 'Microsoft® Word for Office 365', 'creationdate': '2020-06-16T08:54:00+10:00', 'author': 'levertod', 'keywords': 'medical oncology handbook,medical oncology townsville,oncology handbook townsville,', 'moddate': '2020-11-04T13:50:35+10:00', 'subject': 'Medical Oncology Handbook for Junior Medical Officers | THHS', 'title': 'Medical Oncology Handbook for Junior Medical Officers | THHS', 'source': 'C:\\Personal\\AI_Handson\\Projects\\Medical_Chatbot_with_Langchain\\data\\Medical_Oncology_Handbook_.pdf', 'total_pages': 52, 'page': 0, 'page_label': '1'}

# %%
embedding_model = HuggingFaceEmbeddings(
    model_name="BAAI/bge-small-en",
    model_kwargs={"device": "cpu"},
    encode_kwargs={"normalize_embeddings": True}
)
# Out:
# Loading weights: 100%|██████████| 199/199 [00:00<00:00, 463.20it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: BAAI/bge-small-en
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
vector_db = FAISS.from_documents(
    text,
    embedding_model
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Personal\anaconda3\envs\medibot\Lib\site-packages\langchain_community\vectorstores\faiss.py:56, in dependable_faiss_import(no_avx2)
#      55     else:
# ---> 56         import faiss
#      57 except ImportError:
#
# ModuleNotFoundError: No module named 'faiss'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 vector_db = FAISS.from_documents(
#       2     text,
#       3     embedding_model
#       4 )
#
# File c:\Personal\anaconda3\envs\medibot\Lib\site-packages\langchain_core\vectorstores\base.py:814, in VectorStore.from_documents(cls, documents, embedding, **kwargs)
#     811     if any(ids):
#     812         kwargs["ids"] = ids
# ...

# %%
query = "How do we test LLM systems?"

results = vector_db.similarity_search(query, k=2)

for r in results:
    print(r.page_content)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[76], line 3
#       1 query = "How do we test LLM systems?"
# ----> 3 results = vector_db.similarity_search(query, k=2)
#       5 for r in results:
#       6     print(r.page_content)
#
# NameError: name 'vector_db' is not defined
